# %% [markdown]
# ## Challenge 6: Deliverable 1: Retrieve City-Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

sys.path.insert(0, '../' )
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 721

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_current_description = city_weather["weather"][0]["description"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Current Description": city_current_description,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bandarbeyla
# Processing Record 2 of Set 1 | komsomolskiy
# Processing Record 3 of Set 1 | manaus
# Processing Record 4 of Set 1 | quthing
# Processing Record 5 of Set 1 | aguimes
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | tezu
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | port shepstone
# Processing Record 11 of Set 1 | haines junction
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | harare
# Processing Record 14 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | aasiaat
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | qasigiannguit
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | abha
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | bamberg
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | contepec
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | mitsamiouli
# Processing Record 37 of Set 1 | karratha
# Processing Record 38 of Set 1 | haileybury
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | namibe
# Processing Record 41 of Set 1 | khatanga
# Processing Record 42 of Set 1 | goderich
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | pangody
# Processing Record 46 of Set 1 | nizhniy odes
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | msanga
# Processing Record 50 of Set 1 | la joya
# Processing Record 1 of Set 2 | tabou
# Processing Record 2 of Set 2 | mwingi
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | geraldton
# Processing Record 6 of Set 2 | cherskiy
# Processing Record 7 of Set 2 | nedjo
# Processing Record 8 of Set 2 | cabo san lucas
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | sabha
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | inongo
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | dyurtyuli
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | praia da vitoria
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | chumikan
# Processing Record 21 of Set 2 | ilhabela
# Processing Record 22 of Set 2 | zhitikara
# City not found. Skipping...
# Processing Record 23 of Set 2 | beringovskiy
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | thinadhoo
# Processing Record 26 of Set 2 | ous
# Processing Record 27 of Set 2 | kachug
# Processing Record 28 of Set 2 | snizhne
# Processing Record 29 of Set 2 | punta arenas
# Processing Record 30 of Set 2 | anadyr
# Processing Record 31 of Set 2 | hami
# Processing Record 32 of Set 2 | mount isa
# Processing Record 33 of Set 2 | mount gambier
# Processing Record 34 of Set 2 | bowen
# Processing Record 35 of Set 2 | abalak
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | cockburn town
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | pangnirtung
# Processing Record 40 of Set 2 | samarai
# Processing Record 41 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 2 | buala
# Processing Record 43 of Set 2 | naze
# Processing Record 44 of Set 2 | olafsvik
# Processing Record 45 of Set 2 | aviles
# Processing Record 46 of Set 2 | mandalgovi
# Processing Record 47 of Set 2 | mao
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | nome
# Processing Record 50 of Set 2 | kavieng
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | sicamous
# Processing Record 3 of Set 3 | luoyang
# Processing Record 4 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 3 | linguere
# Processing Record 6 of Set 3 | lasa
# Processing Record 7 of Set 3 | nishihara
# Processing Record 8 of Set 3 | methoni
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | selishche
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | ostersund
# Processing Record 13 of Set 3 | mwense
# Processing Record 14 of Set 3 | bambanglipuro
# Processing Record 15 of Set 3 | bose
# Processing Record 16 of Set 3 | bombay
# Processing Record 17 of Set 3 | saint anthony
# Processing Record 18 of Set 3 | pucallpa
# Processing Record 19 of Set 3 | itarema
# Processing Record 20 of Set 3 | porto torres
# Processing Record 21 of Set 3 | zabaykalsk
# Processing Record 22 of Set 3 | colares
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | sitka
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | provideniya
# Processing Record 31 of Set 3 | constitucion
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | otjiwarongo
# Processing Record 34 of Set 3 | hovd
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | thompson
# Processing Record 37 of Set 3 | tuatapere
# Processing Record 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 3 | roma
# Processing Record 41 of Set 3 | lata
# Processing Record 42 of Set 3 | baikunthpur
# Processing Record 43 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 3 | chunskiy
# Processing Record 45 of Set 3 | mulanje
# Processing Record 46 of Set 3 | hailar
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | bangolo
# Processing Record 49 of Set 3 | carutapera
# Processing Record 50 of Set 3 | lebu
# Processing Record 1 of Set 4 | batemans bay
# Processing Record 2 of Set 4 | manacapuru
# Processing Record 3 of Set 4 | seoul
# Processing Record 4 of Set 4 | mogadishu
# Processing Record 5 of Set 4 | sakakah
# Processing Record 6 of Set 4 | pasni
# Processing Record 7 of Set 4 | zaysan
# Processing Record 8 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 9 of Set 4 | morros
# Processing Record 10 of Set 4 | nizhniy chir
# Processing Record 11 of Set 4 | lumby
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | jiujiang
# Processing Record 14 of Set 4 | sao filipe
# Processing Record 15 of Set 4 | candelaria
# Processing Record 16 of Set 4 | touros
# Processing Record 17 of Set 4 | krasnyy chikoy
# Processing Record 18 of Set 4 | villafranca de los barros
# Processing Record 19 of Set 4 | saint-philippe
# Processing Record 20 of Set 4 | torbay
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | winchester
# Processing Record 24 of Set 4 | qaanaaq
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | gardan diwal
# City not found. Skipping...
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | zyryanka
# Processing Record 29 of Set 4 | alice springs
# Processing Record 30 of Set 4 | zavitinsk
# Processing Record 31 of Set 4 | bogorodskoye
# Processing Record 32 of Set 4 | mahebourg
# Processing Record 33 of Set 4 | brosteni
# Processing Record 34 of Set 4 | bakel
# Processing Record 35 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 4 | sosnogorsk
# Processing Record 37 of Set 4 | formosa
# Processing Record 38 of Set 4 | jaru
# Processing Record 39 of Set 4 | chokurdakh
# Processing Record 40 of Set 4 | klaksvik
# Processing Record 41 of Set 4 | plouzane
# Processing Record 42 of Set 4 | liberal
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | nizhniy tsasuchey
# Processing Record 45 of Set 4 | ratnagiri
# Processing Record 46 of Set 4 | yellowknife
# Processing Record 47 of Set 4 | kaeo
# Processing Record 48 of Set 4 | richards bay
# Processing Record 49 of Set 4 | urengoy
# Processing Record 50 of Set 4 | pisco
# Processing Record 1 of Set 5 | gamba
# Processing Record 2 of Set 5 | berlevag
# Processing Record 3 of Set 5 | domoni
# Processing Record 4 of Set 5 | kapit
# Processing Record 5 of Set 5 | lagos
# Processing Record 6 of Set 5 | kapaa
# Processing Record 7 of Set 5 | bonfim
# Processing Record 8 of Set 5 | viedma
# Processing Record 9 of Set 5 | nanortalik
# Processing Record 10 of Set 5 | hamilton
# Processing Record 11 of Set 5 | beloha
# Processing Record 12 of Set 5 | tiksi
# Processing Record 13 of Set 5 | salalah
# Processing Record 14 of Set 5 | darhan
# Processing Record 15 of Set 5 | nyurba
# Processing Record 16 of Set 5 | paamiut
# Processing Record 17 of Set 5 | trairi
# Processing Record 18 of Set 5 | sao felix do xingu
# Processing Record 19 of Set 5 | north bend
# Processing Record 20 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 5 | rockhampton
# Processing Record 22 of Set 5 | madera
# Processing Record 23 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 5 | korla
# Processing Record 25 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 5 | ubinskoye
# Processing Record 27 of Set 5 | paita
# Processing Record 28 of Set 5 | luena
# Processing Record 29 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 5 | los llanos de aridane
# Processing Record 31 of Set 5 | severo-kurilsk
# Processing Record 32 of Set 5 | areosa
# Processing Record 33 of Set 5 | madimba
# Processing Record 34 of Set 5 | taoudenni
# Processing Record 35 of Set 5 | benguela
# Processing Record 36 of Set 5 | ulladulla
# Processing Record 37 of Set 5 | chino valley
# Processing Record 38 of Set 5 | mahajanga
# Processing Record 39 of Set 5 | nemuro
# Processing Record 40 of Set 5 | kahului
# Processing Record 41 of Set 5 | lavrentiya
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | nabire
# Processing Record 44 of Set 5 | ji-parana
# City not found. Skipping...
# Processing Record 45 of Set 5 | krasnaya gora
# Processing Record 46 of Set 5 | yerofey pavlovich
# Processing Record 47 of Set 5 | pokhara
# Processing Record 48 of Set 5 | flin flon
# Processing Record 49 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 1 of Set 6 | maues
# Processing Record 2 of Set 6 | nizwa
# Processing Record 3 of Set 6 | montepuez
# Processing Record 4 of Set 6 | lagoa
# Processing Record 5 of Set 6 | petropavlovka
# Processing Record 6 of Set 6 | bethel
# Processing Record 7 of Set 6 | castro
# Processing Record 8 of Set 6 | tiznit
# Processing Record 9 of Set 6 | husavik
# Processing Record 10 of Set 6 | carballo
# Processing Record 11 of Set 6 | brae
# Processing Record 12 of Set 6 | terra santa
# Processing Record 13 of Set 6 | acarau
# Processing Record 14 of Set 6 | norman wells
# Processing Record 15 of Set 6 | zyryanovsk
# Processing Record 16 of Set 6 | waingapu
# Processing Record 17 of Set 6 | lumeje
# Processing Record 18 of Set 6 | kamenka
# Processing Record 19 of Set 6 | itacarambi
# Processing Record 20 of Set 6 | pryazha
# Processing Record 21 of Set 6 | luderitz
# Processing Record 22 of Set 6 | husum
# Processing Record 23 of Set 6 | anavra
# Processing Record 24 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 6 | awbari
# Processing Record 26 of Set 6 | sola
# Processing Record 27 of Set 6 | shakawe
# Processing Record 28 of Set 6 | san luis
# Processing Record 29 of Set 6 | half moon bay
# Processing Record 30 of Set 6 | katsuura
# Processing Record 31 of Set 6 | kukushtan
# Processing Record 32 of Set 6 | tura
# Processing Record 33 of Set 6 | atambua
# Processing Record 34 of Set 6 | imperia
# Processing Record 35 of Set 6 | tarko-sale
# Processing Record 36 of Set 6 | coquimbo
# Processing Record 37 of Set 6 | achisay
# City not found. Skipping...
# Processing Record 38 of Set 6 | san jeronimo
# Processing Record 39 of Set 6 | grindavik
# Processing Record 40 of Set 6 | oranjemund
# Processing Record 41 of Set 6 | wenling
# Processing Record 42 of Set 6 | crepy-en-valois
# Processing Record 43 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 6 | clyde river
# Processing Record 45 of Set 6 | broome
# Processing Record 46 of Set 6 | saint george
# Processing Record 47 of Set 6 | rocha
# Processing Record 48 of Set 6 | ugoofaaru
# Processing Record 49 of Set 6 | zarubino
# Processing Record 50 of Set 6 | poum
# Processing Record 1 of Set 7 | dumas
# Processing Record 2 of Set 7 | hambantota
# Processing Record 3 of Set 7 | iralaya
# Processing Record 4 of Set 7 | kavaratti
# Processing Record 5 of Set 7 | saint-joseph
# Processing Record 6 of Set 7 | contamana
# Processing Record 7 of Set 7 | dikson
# Processing Record 8 of Set 7 | ukiah
# Processing Record 9 of Set 7 | tsabong
# Processing Record 10 of Set 7 | padang
# Processing Record 11 of Set 7 | benidorm
# Processing Record 12 of Set 7 | mecca
# Processing Record 13 of Set 7 | bathsheba
# Processing Record 14 of Set 7 | malpura
# Processing Record 15 of Set 7 | saint-augustin
# Processing Record 16 of Set 7 | ixtapa
# Processing Record 17 of Set 7 | muzhi
# Processing Record 18 of Set 7 | surt
# Processing Record 19 of Set 7 | ransang
# Processing Record 20 of Set 7 | nelson bay
# Processing Record 21 of Set 7 | maceio
# Processing Record 22 of Set 7 | tambopata
# Processing Record 23 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 7 | port hawkesbury
# Processing Record 25 of Set 7 | selizharovo
# Processing Record 26 of Set 7 | dungarvan
# Processing Record 27 of Set 7 | kuminskiy
# Processing Record 28 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 7 | ternate
# Processing Record 30 of Set 7 | ritchie
# Processing Record 31 of Set 7 | necochea
# Processing Record 32 of Set 7 | ahuimanu
# Processing Record 33 of Set 7 | waipawa
# Processing Record 34 of Set 7 | bom jesus
# Processing Record 35 of Set 7 | chapais
# Processing Record 36 of Set 7 | victoria
# Processing Record 37 of Set 7 | floresta
# Processing Record 38 of Set 7 | shellbrook
# Processing Record 39 of Set 7 | kenai
# Processing Record 40 of Set 7 | puerto escondido
# Processing Record 41 of Set 7 | abaza
# Processing Record 42 of Set 7 | moscow
# Processing Record 43 of Set 7 | porec
# Processing Record 44 of Set 7 | butajira
# Processing Record 45 of Set 7 | kilindoni
# Processing Record 46 of Set 7 | pacific grove
# Processing Record 47 of Set 7 | bernal
# Processing Record 48 of Set 7 | royal palm beach
# Processing Record 49 of Set 7 | bayir
# Processing Record 50 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 8 | mehamn
# Processing Record 2 of Set 8 | namuac
# Processing Record 3 of Set 8 | waitati
# Processing Record 4 of Set 8 | umm kaddadah
# Processing Record 5 of Set 8 | raichur
# Processing Record 6 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 7 of Set 8 | eisiskes
# Processing Record 8 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 8 | qena
# Processing Record 10 of Set 8 | narsaq
# Processing Record 11 of Set 8 | guanica
# Processing Record 12 of Set 8 | verkhoyansk
# Processing Record 13 of Set 8 | bucerias
# Processing Record 14 of Set 8 | xai-xai
# Processing Record 15 of Set 8 | iqaluit
# Processing Record 16 of Set 8 | tecoanapa
# Processing Record 17 of Set 8 | laem sing
# Processing Record 18 of Set 8 | panama city
# Processing Record 19 of Set 8 | cap malheureux
# Processing Record 20 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 8 | yelatma
# Processing Record 22 of Set 8 | kirakira
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | lengshuijiang
# Processing Record 25 of Set 8 | sistranda
# Processing Record 26 of Set 8 | vestmannaeyjar
# Processing Record 27 of Set 8 | kristianstad
# Processing Record 28 of Set 8 | la asuncion
# Processing Record 29 of Set 8 | policarpa
# Processing Record 30 of Set 8 | stephenville
# Processing Record 31 of Set 8 | coihaique
# Processing Record 32 of Set 8 | natal
# Processing Record 33 of Set 8 | iquitos
# Processing Record 34 of Set 8 | teopantlan
# Processing Record 35 of Set 8 | hun
# Processing Record 36 of Set 8 | gualeguaychu
# Processing Record 37 of Set 8 | airai
# Processing Record 38 of Set 8 | prince george
# Processing Record 39 of Set 8 | znamenskoye
# Processing Record 40 of Set 8 | ketchikan
# Processing Record 41 of Set 8 | kathu
# Processing Record 42 of Set 8 | berdyuzhye
# City not found. Skipping...
# Processing Record 43 of Set 8 | dunmore east
# Processing Record 44 of Set 8 | lorengau
# Processing Record 45 of Set 8 | san quintin
# Processing Record 46 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 47 of Set 8 | te anau
# Processing Record 48 of Set 8 | khasan
# Processing Record 49 of Set 8 | rafaela
# Processing Record 50 of Set 8 | monrovia
# Processing Record 1 of Set 9 | kaitangata
# Processing Record 2 of Set 9 | fairview
# Processing Record 3 of Set 9 | homer
# Processing Record 4 of Set 9 | kasempa
# Processing Record 5 of Set 9 | srednekolymsk
# Processing Record 6 of Set 9 | lalibela
# Processing Record 7 of Set 9 | kalmunai
# Processing Record 8 of Set 9 | tagusao
# Processing Record 9 of Set 9 | novorozhdestvenskaya
# Processing Record 10 of Set 9 | kalaleh
# Processing Record 11 of Set 9 | hanna
# Processing Record 12 of Set 9 | pochutla
# Processing Record 13 of Set 9 | pampierstad
# Processing Record 14 of Set 9 | murree
# Processing Record 15 of Set 9 | la mata
# Processing Record 16 of Set 9 | voh
# Processing Record 17 of Set 9 | santa maria
# Processing Record 18 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 19 of Set 9 | vallenar
# Processing Record 20 of Set 9 | lewistown
# Processing Record 21 of Set 9 | santa rosa
# Processing Record 22 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 9 | ceyranbatan
# Processing Record 24 of Set 9 | havoysund
# Processing Record 25 of Set 9 | leningradskiy
# Processing Record 26 of Set 9 | riyaq
# City not found. Skipping...
# Processing Record 27 of Set 9 | matadi
# Processing Record 28 of Set 9 | high level
# Processing Record 29 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 9 | shush
# Processing Record 31 of Set 9 | makakilo city
# Processing Record 32 of Set 9 | auki
# Processing Record 33 of Set 9 | fortuna
# Processing Record 34 of Set 9 | veraval
# Processing Record 35 of Set 9 | gawler
# Processing Record 36 of Set 9 | berbera
# Processing Record 37 of Set 9 | alofi
# Processing Record 38 of Set 9 | male
# Processing Record 39 of Set 9 | harper
# Processing Record 40 of Set 9 | aksarka
# Processing Record 41 of Set 9 | tari
# Processing Record 42 of Set 9 | sao gabriel da cachoeira
# Processing Record 43 of Set 9 | hasaki
# Processing Record 44 of Set 9 | vazante
# Processing Record 45 of Set 9 | pevek
# Processing Record 46 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 9 | college
# Processing Record 49 of Set 9 | guerrero negro
# Processing Record 50 of Set 9 | malinovoye ozero
# Processing Record 1 of Set 10 | novobataysk
# Processing Record 2 of Set 10 | sur
# Processing Record 3 of Set 10 | carnarvon
# Processing Record 4 of Set 10 | flinders
# Processing Record 5 of Set 10 | praya
# Processing Record 6 of Set 10 | mayo
# Processing Record 7 of Set 10 | grand forks
# Processing Record 8 of Set 10 | zinder
# Processing Record 9 of Set 10 | victor harbor
# Processing Record 10 of Set 10 | floridablanca
# Processing Record 11 of Set 10 | tripoli
# Processing Record 12 of Set 10 | trat
# Processing Record 13 of Set 10 | amuntai
# Processing Record 14 of Set 10 | kloulklubed
# Processing Record 15 of Set 10 | kodinsk
# Processing Record 16 of Set 10 | crotone
# Processing Record 17 of Set 10 | quatre cocos
# Processing Record 18 of Set 10 | buraydah
# Processing Record 19 of Set 10 | puerto madero
# Processing Record 20 of Set 10 | edgewater
# Processing Record 21 of Set 10 | quang ngai
# Processing Record 22 of Set 10 | qaqortoq
# Processing Record 23 of Set 10 | pont-saint-esprit
# Processing Record 24 of Set 10 | elat
# Processing Record 25 of Set 10 | aswan
# Processing Record 26 of Set 10 | fairbanks
# Processing Record 27 of Set 10 | moose jaw
# Processing Record 28 of Set 10 | ahipara
# Processing Record 29 of Set 10 | adrar
# Processing Record 30 of Set 10 | zhigansk
# Processing Record 31 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 10 | zhanaozen
# Processing Record 33 of Set 10 | luangwa
# Processing Record 34 of Set 10 | saiha
# Processing Record 35 of Set 10 | vardo
# Processing Record 36 of Set 10 | grand baie
# Processing Record 37 of Set 10 | tarauaca
# Processing Record 38 of Set 10 | si satchanalai
# Processing Record 39 of Set 10 | birao
# Processing Record 40 of Set 10 | poletayevo
# Processing Record 41 of Set 10 | vila franca do campo
# Processing Record 42 of Set 10 | xinzhou
# Processing Record 43 of Set 10 | daru
# Processing Record 44 of Set 10 | zaozerne
# Processing Record 45 of Set 10 | wad rawah
# Processing Record 46 of Set 10 | qui nhon
# Processing Record 47 of Set 10 | vredendal
# Processing Record 48 of Set 10 | chisinau
# Processing Record 49 of Set 10 | okato
# Processing Record 50 of Set 10 | warwick
# Processing Record 1 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 11 | fort-shevchenko
# Processing Record 3 of Set 11 | honiara
# Processing Record 4 of Set 11 | santa
# Processing Record 5 of Set 11 | erdenet
# Processing Record 6 of Set 11 | tilichiki
# Processing Record 7 of Set 11 | kadi
# Processing Record 8 of Set 11 | hatillo
# Processing Record 9 of Set 11 | marga
# Processing Record 10 of Set 11 | bilibino
# Processing Record 11 of Set 11 | grand-santi
# Processing Record 12 of Set 11 | cairns
# Processing Record 13 of Set 11 | sulangan
# Processing Record 14 of Set 11 | tommot
# Processing Record 15 of Set 11 | hualmay
# Processing Record 16 of Set 11 | port hedland
# Processing Record 17 of Set 11 | miles city
# Processing Record 18 of Set 11 | west wendover
# Processing Record 19 of Set 11 | altay
# Processing Record 20 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | herat
# Processing Record 22 of Set 11 | figeac
# Processing Record 23 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 24 of Set 11 | tessalit
# Processing Record 25 of Set 11 | kuldur
# Processing Record 26 of Set 11 | batagay
# Processing Record 27 of Set 11 | yeppoon
# Processing Record 28 of Set 11 | ludvika
# Processing Record 29 of Set 11 | solnechnyy
# Processing Record 30 of Set 11 | la rioja
# Processing Record 31 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 32 of Set 11 | somerset
# Processing Record 33 of Set 11 | hirara
# Processing Record 34 of Set 11 | douglas
# Processing Record 35 of Set 11 | providencia
# Processing Record 36 of Set 11 | dixon
# Processing Record 37 of Set 11 | dryden
# Processing Record 38 of Set 11 | port blair
# Processing Record 39 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 40 of Set 11 | saint-michel-des-saints
# Processing Record 41 of Set 11 | kholtoson
# Processing Record 42 of Set 11 | camacha
# Processing Record 43 of Set 11 | wattegama
# Processing Record 44 of Set 11 | balclutha
# Processing Record 45 of Set 11 | marawi
# Processing Record 46 of Set 11 | moussoro
# Processing Record 47 of Set 11 | narasannapeta
# Processing Record 48 of Set 11 | yarada
# Processing Record 49 of Set 11 | parabel
# Processing Record 50 of Set 11 | essex
# Processing Record 1 of Set 12 | sorong
# Processing Record 2 of Set 12 | raudeberg
# Processing Record 3 of Set 12 | rehoboth
# Processing Record 4 of Set 12 | sunggal
# Processing Record 5 of Set 12 | greenville
# Processing Record 6 of Set 12 | nantucket
# Processing Record 7 of Set 12 | batken
# Processing Record 8 of Set 12 | alakurtti
# Processing Record 9 of Set 12 | moose factory
# Processing Record 10 of Set 12 | chilia veche
# Processing Record 11 of Set 12 | mabaruma
# Processing Record 12 of Set 12 | nakhon phanom
# Processing Record 13 of Set 12 | olinda
# Processing Record 14 of Set 12 | koumac
# Processing Record 15 of Set 12 | fukue
# Processing Record 16 of Set 12 | norrtalje
# Processing Record 17 of Set 12 | kibakwe
# Processing Record 18 of Set 12 | tyrma
# Processing Record 19 of Set 12 | ischia
# Processing Record 20 of Set 12 | paracatu
# Processing Record 21 of Set 12 | charters towers
# Processing Record 22 of Set 12 | catuday
# Processing Record 23 of Set 12 | urumqi
# Processing Record 24 of Set 12 | elk river
# Processing Record 25 of Set 12 | sompeta
# Processing Record 26 of Set 12 | vondrozo
# Processing Record 27 of Set 12 | deputatskiy
# Processing Record 28 of Set 12 | opuwo
# Processing Record 29 of Set 12 | rochegda
# Processing Record 30 of Set 12 | marsh harbour
# Processing Record 31 of Set 12 | bonavista
# Processing Record 32 of Set 12 | ostrovnoy
# Processing Record 33 of Set 12 | alyangula
# Processing Record 34 of Set 12 | krasnovishersk
# Processing Record 35 of Set 12 | brownsville
# Processing Record 36 of Set 12 | karagaylinskiy
# Processing Record 37 of Set 12 | ponta delgada
# Processing Record 38 of Set 12 | souillac
# Processing Record 39 of Set 12 | oriximina
# Processing Record 40 of Set 12 | chuncheng
# Processing Record 41 of Set 12 | karaman
# Processing Record 42 of Set 12 | grand gaube
# Processing Record 43 of Set 12 | kalabo
# Processing Record 44 of Set 12 | mandapam
# Processing Record 45 of Set 12 | dayong
# Processing Record 46 of Set 12 | bozuyuk
# Processing Record 47 of Set 12 | meadow lake
# Processing Record 48 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 49 of Set 12 | cozumel
# Processing Record 50 of Set 12 | port lincoln
# Processing Record 1 of Set 13 | san policarpo
# Processing Record 2 of Set 13 | byron bay
# Processing Record 3 of Set 13 | tual
# Processing Record 4 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 13 | ust-tsilma
# Processing Record 6 of Set 13 | mackay
# Processing Record 7 of Set 13 | srikakulam
# Processing Record 8 of Set 13 | nantou
# Processing Record 9 of Set 13 | westport
# Processing Record 10 of Set 13 | tiarei
# Processing Record 11 of Set 13 | palana
# Processing Record 12 of Set 13 | maningrida
# Processing Record 13 of Set 13 | helena
# Processing Record 14 of Set 13 | birin
# Processing Record 15 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 13 | vestmanna
# Processing Record 17 of Set 13 | ekibastuz
# Processing Record 18 of Set 13 | muros
# Processing Record 19 of Set 13 | la tuque
# Processing Record 20 of Set 13 | cayenne
# Processing Record 21 of Set 13 | san cristobal
# Processing Record 22 of Set 13 | palmer
# Processing Record 23 of Set 13 | nanakuli
# Processing Record 24 of Set 13 | fez
# Processing Record 25 of Set 13 | launceston
# Processing Record 26 of Set 13 | dalen
# Processing Record 27 of Set 13 | sabang
# Processing Record 28 of Set 13 | fortuna foothills
# Processing Record 29 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 13 | yining
# Processing Record 31 of Set 13 | hohhot
# Processing Record 32 of Set 13 | camacari
# Processing Record 33 of Set 13 | hofn
# Processing Record 34 of Set 13 | ulaangom
# Processing Record 35 of Set 13 | margate
# Processing Record 36 of Set 13 | lincoln
# Processing Record 37 of Set 13 | qax
# Processing Record 38 of Set 13 | bassila
# Processing Record 39 of Set 13 | lalomanu
# City not found. Skipping...
# Processing Record 40 of Set 13 | athabasca
# Processing Record 41 of Set 13 | brewster
# Processing Record 42 of Set 13 | sovetskiy
# Processing Record 43 of Set 13 | banda aceh
# Processing Record 44 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 13 | erenhot
# Processing Record 46 of Set 13 | stilis
# City not found. Skipping...
# Processing Record 47 of Set 13 | boshnyakovo
# Processing Record 48 of Set 13 | williams lake
# Processing Record 49 of Set 13 | bosaso
# Processing Record 50 of Set 13 | usinsk
# Processing Record 1 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 2 of Set 14 | dillon
# Processing Record 3 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 4 of Set 14 | fasa
# Processing Record 5 of Set 14 | batagay-alyta
# Processing Record 6 of Set 14 | beidao
# Processing Record 7 of Set 14 | murgab
# Processing Record 8 of Set 14 | aranos
# Processing Record 9 of Set 14 | cape coast
# Processing Record 10 of Set 14 | achacachi
# Processing Record 11 of Set 14 | magadan
# Processing Record 12 of Set 14 | presidente franco
# Processing Record 13 of Set 14 | bershet
# Processing Record 14 of Set 14 | jackson
# Processing Record 15 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 14 | katobu
# Processing Record 17 of Set 14 | baboua
# City not found. Skipping...
# Processing Record 18 of Set 14 | namatanai
# Processing Record 19 of Set 14 | de aar
# Processing Record 20 of Set 14 | eastlake
# Processing Record 21 of Set 14 | slave lake
# Processing Record 22 of Set 14 | bardiyah
# Processing Record 23 of Set 14 | taicheng
# Processing Record 24 of Set 14 | saint-francois
# Processing Record 25 of Set 14 | luanda
# Processing Record 26 of Set 14 | isangel
# Processing Record 27 of Set 14 | nsanje
# Processing Record 28 of Set 14 | kirovskiy
# Processing Record 29 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 30 of Set 14 | reconquista
# Processing Record 31 of Set 14 | roald
# Processing Record 32 of Set 14 | trogir
# Processing Record 33 of Set 14 | el alto
# Processing Record 34 of Set 14 | haimen
# Processing Record 35 of Set 14 | palu
# Processing Record 36 of Set 14 | turayf
# Processing Record 37 of Set 14 | saint-pierre
# Processing Record 38 of Set 14 | santa cruz
# Processing Record 39 of Set 14 | kilrush
# Processing Record 40 of Set 14 | verkhnetulomskiy
# Processing Record 41 of Set 14 | vila
# Processing Record 42 of Set 14 | altea
# Processing Record 43 of Set 14 | tabuk
# Processing Record 44 of Set 14 | dingle
# Processing Record 45 of Set 14 | ballitoville
# Processing Record 46 of Set 14 | santa lucia
# Processing Record 47 of Set 14 | ust-kan
# Processing Record 48 of Set 14 | camalu
# Processing Record 49 of Set 14 | mallow
# Processing Record 50 of Set 14 | levelland
# Processing Record 1 of Set 15 | maneadero
# Processing Record 2 of Set 15 | sagaing
# Processing Record 3 of Set 15 | sao jose da coroa grande
# Processing Record 4 of Set 15 | solvychegodsk
# Processing Record 5 of Set 15 | sinnamary
# Processing Record 6 of Set 15 | ouadda
# Processing Record 7 of Set 15 | yar-sale
# Processing Record 8 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 9 of Set 15 | jiangyou
# Processing Record 10 of Set 15 | placido de castro
# Processing Record 11 of Set 15 | vanimo
# Processing Record 12 of Set 15 | taitung
# Processing Record 13 of Set 15 | portland
# Processing Record 14 of Set 15 | antalaha
# Processing Record 15 of Set 15 | valday
# Processing Record 16 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 15 | atherton
# Processing Record 18 of Set 15 | lazaro cardenas
# Processing Record 19 of Set 15 | tarpon springs
# Processing Record 20 of Set 15 | gat
# Processing Record 21 of Set 15 | moindou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 659

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Bandarbeyla   9.4942   50.8122     81.46        65          71
# 1    Komsomolskiy  40.4272   71.7189     88.52        20           0
# 2          Manaus  -3.1019  -60.0250     81.09        89         100
# 3         Quthing -30.4000   27.7003     61.86        12           0
# 4         Aguimes  27.9054  -15.4461     74.66        88          40
# 5     Port Alfred -33.5906   26.8910     64.18        55          30
# 6            Tezu  27.9167   96.1667     76.86        97         100
# 7        Bengkulu  -3.8004  102.2655     79.07        81          86
# 8  Ribeira Grande  38.5167  -28.7000     77.40        78          20
# 9  Port Shepstone -30.7414   30.4550     63.57        55          53
#
#   Current Description  Wind Speed Country                 Date
# 0       broken clouds       29.21      SO  2022-08-31 11:56:46
# 1           clear sky        4.61      UZ  2022-08-31 11:56:46
# 2     overcast clouds        5.75      BR  2022-08-31 11:55:06
# 3           clear sky        4.03      LS  2022-08-31 11:56:47
# 4    scattered clouds       10.36      ES  2022-08-31 11:56:47
# 5    scattered clouds        5.99      ZA  2022-08-31 11:56:47
# 6     overcast clouds        2.51      IN  2022-08-31 11:56:47
# 7       moderate rain        0.74      ID  2022-08-31 11:56:48
# 8          few clouds        8.05      PT  2022-08-31 11:56:48
# 9       broken clouds       15.52      ZA  2022-08-31 11:56:48

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   Bandarbeyla      SO   9.4942  50.8122     81.46        65          71
# 1  Komsomolskiy      UZ  40.4272  71.7189     88.52        20           0
# 2        Manaus      BR  -3.1019 -60.0250     81.09        89         100
# 3       Quthing      LS -30.4000  27.7003     61.86        12           0
# 4       Aguimes      ES  27.9054 -15.4461     74.66        88          40
#
#    Wind Speed Current Description
# 0       29.21       broken clouds
# 1        4.61           clear sky
# 2        5.75     overcast clouds
# 3        4.03           clear sky
# 4       10.36    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
